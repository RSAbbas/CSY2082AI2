# %% [markdown]
# Loading the dataset, In this I have taken images of the celebrities namely Mark ruffalo, micheal b jordan and daisy jones from the surface web which i web scraped through a chrome extension.

# %%
# !pip install tensorflow

# %%
# !pip install --upgrade numpy
# Out:
# ...
#      --------------------------------------- 12.9/12.9 MB 12.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\family\\anaconda3\\Lib\\site-packages\\~umpy.libs\\libscipy_openblas64_-caad452230ae4ddb57899b8b3a33c55c.dll'
# Consider using the `--user` option or check the permissions.

# %%
from tensorflow.keras.utils import image_dataset_from_directory


dataset_path = r"C:\Users\family\Desktop\AIPRO2\dataset" 

# Load dataset
dataset = image_dataset_from_directory(
    dataset_path,
    image_size=(180, 180),  # Resize images to a consistent size
    batch_size=32,          # Number of images per batch
    validation_split=0.2,   # Split off 20% of data for validation
    subset="training",      # Specify which subset to load (training or validation)
    seed=123                # Random seed for reproducibility
)

# Load validation dataset
val_dataset = image_dataset_from_directory(
    dataset_path,
    image_size=(180, 180),
    batch_size=32,
    validation_split=0.2,
    subset="validation",
    seed=123
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from tensorflow.keras.utils import image_dataset_from_directory
#       4 dataset_path = r"C:\Users\family\Desktop\AIPRO2\dataset"
#       6 # Load dataset
#
# File ~\anaconda3\lib\site-packages\keras\_tf_keras\keras\__init__.py:7
#       1 """DO NOT EDIT.
#       2
#       3 This file was autogenerated. Do not edit it by hand,
#       4 since your modifications would be overwritten.
#       5 """
# ----> 7 from keras.api import activations
#       8 from keras.api import applications
#       9 from keras.api import callbacks
#
# File ~\anaconda3\lib\site-packages\keras\__init__.py:2
#       1 # DO NOT EDIT. Generated by api_gen.sh
# ----> 2 from keras.api import DTypePolicy
#       3 from keras.api import FloatDTypePolicy
#       4 from keras.api import Function
#
# ...
